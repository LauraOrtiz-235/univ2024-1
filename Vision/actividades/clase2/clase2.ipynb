# %%
import skimage.io
import cv2
import numpy as np
import matplotlib.pyplot as plt
from skimage.filters import try_all_threshold
from skimage import color
from skimage import filters

# %%
img = plt.imread('imagen3.jpg')
img_gray = color.rgb2gray(img)

# %%
ax, fig = try_all_threshold(img_gray, figsize=(10, 10), verbose=False)

# %%
filters.sobel(img)
# Out:
# array([[[0.10584935, 0.16913322, 0.22191684],
#         [0.1222172 , 0.18272636, 0.2341448 ],
#         [0.12453706, 0.18827912, 0.23962597],
#         ...,
#         [0.1980107 , 0.17876969, 0.0463771 ],
#         [0.19773382, 0.17748635, 0.03376398],
#         [0.2017338 , 0.18203817, 0.05080412]],
#
#        [[0.08185002, 0.15634873, 0.21090265],
#         [0.0921586 , 0.16536109, 0.21898693],
#         [0.09935504, 0.17425643, 0.22757438],
#         ...,
#         [0.1935596 , 0.17648483, 0.04532724],
#         [0.19719454, 0.17881029, 0.04652991],
#         [0.1993598 , 0.18144055, 0.05356089]],
#
#        [[0.11945531, 0.18583583, 0.23377381],
#         [0.10586041, 0.18098262, 0.2306906 ],
#         [0.0983902 , 0.17971392, 0.22989116],
#         ...,
#         [0.18373353, 0.16995789, 0.02147559],
#         [0.18905788, 0.17444944, 0.03735447],
#         [0.19301031, 0.17763054, 0.04894111]],
#
#        ...,
#
#        [[0.10579154, 0.15254999, 0.19545899],
#         [0.09416189, 0.14657519, 0.19161317],
#         [0.05579342, 0.12873909, 0.18018068],
#         ...,
#         [0.10423863, 0.07936132, 0.02527562],
#         [0.10439834, 0.07957097, 0.02592638],
#         [0.10437378, 0.07953875, 0.02582733]],
#
#        [[0.06949498, 0.13275779, 0.18249871],
#         [0.06160109, 0.12961462, 0.18016823],
#         [0.06578619, 0.13376037, 0.18373222],
#         ...,
#         [0.10430316, 0.07944605, 0.02554042],
#         [0.1045915 , 0.07982423, 0.02669357],
#         [0.10457006, 0.07979613, 0.02660942]],
#
#        [[0.05307415, 0.12494777, 0.17689854],
#         [0.05256463, 0.12580638, 0.17778018],
#         [0.07327844, 0.13750677, 0.18633986],
#         ...,
#         [0.10432773, 0.07947831, 0.02564058],
#         [0.10457006, 0.07979613, 0.02660942],
#         [0.10434615, 0.07950249, 0.02571545]]])
